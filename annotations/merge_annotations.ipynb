# %% [markdown]
# # Merge Annotation data
#
# This notebook merges in the AWS SageMaker Ground truth responses into the master.csv data set.

# %%
import os
import csv
import json
import pandas as pd
from pprint import pprint

text_df = pd.read_csv("../data/text.csv", header=None)
text_df.columns = ["text"]

# %% [markdown]
# ### First, merge in the opinion-results
#
# **Use compare_texts to verify row order**

# %%
import re

def compare_texts(og_tweet, annot_tweet):
    match = True
    for i in range(len(og_tweet)):
        if re.sub(r"[^a-zA-Z0-9 ]", "", og_tweet[i]) != re.sub(r"[^a-zA-Z0-9 ]", "", annot_tweet[i]):
            print(f"Texts do not match at index {i}")
            match = False
                  
    if match:
        print("All tweet texts match. Rows and columns are aligned!")
        
    return match

# %% [markdown]
# **Merge in SageMaker opinion annotation results**
#
# The `opinion-results.txt` file is the SageMaker identified ground truth results for tweet opinion. It includes the opinion key, opinion label, and a algorithmically assigned confidence score

# %%
with open("opinion-results.txt") as opinion_file:
    rows = opinion_file.readlines()

    annotation_texts = [json.loads(row.strip()).get("source") for row in rows]
    annotation_keys = [json.loads(row.strip()).get("annotate-user-opinion-2") for row in rows]
    annotation_labels = [json.loads(row.strip()).get("annotate-user-opinion-2-metadata").get("class-name") for row in rows]
    annotation_confidences = [json.loads(row.strip()).get("annotate-user-opinion-2-metadata").get("confidence") for row in rows]


text_df["opinion_text"] = annotation_texts 
text_df["opinion_key"] = annotation_keys
text_df["opinion_label"] = annotation_labels
text_df["opinion_annotation_confidence"] = annotation_confidences


matched = compare_texts(text_df["text"], text_df["opinion_text"])

if matched:
    del text_df["opinion_text"]
    
text_df.head()
# Out:
# All tweet texts match. Rows and columns are aligned!
#                                                 text  opinion_key  \
# 0  @MSNBC @MaddowBlog “Simpleton’s defense”?  You...            2
# 1  @MSNBC @MaddowBlog I feel sorry for the sucker...            1
# 2  @MSNBC @MaddowBlog Setting up a 2024 elections...            2
# 3  @MSNBC @MaddowBlog If you can't pay off studen...            1
# 4  @MSNBC @MaddowBlog The simple defense is why s...            0
#
#                       opinion_label  opinion_annotation_confidence
# 0  AGAINST student loan forgiveness                           0.70
# 1                   NEUTRAL support                           0.62
# 2  AGAINST student loan forgiveness                           0.43
# 3                   NEUTRAL support                           0.51
# 4     FOR student loan forgiveness                            0.88

# %% [markdown]
# **Merge in SageMaker ego involvement annotation results**
#
# The `ego-involvement-results.txt` file is the SageMaker identified ground truth results for tweet ego involvement. It includes the annotation key, annotation label, and a algorithmically assigned annotation confidence score

# %%
with open("ego-involvement-results.txt") as ego_file:
    rows = ego_file.readlines()

    annotation_texts = [json.loads(row.strip()).get("source") for row in rows]
    annotation_keys = [json.loads(row.strip()).get("annotate-ego-involvement-2") for row in rows]
    annotation_labels = [json.loads(row.strip()).get("annotate-ego-involvement-2-metadata").get("class-name") for row in rows]
    annotation_confidences = [json.loads(row.strip()).get("annotate-ego-involvement-2-metadata").get("confidence") for row in rows]


text_df["ego_involvement_text"] = annotation_texts 
text_df["ego_involvement_key"] = annotation_keys
text_df["ego_involvement_label"] = annotation_labels
text_df["ego_involvement_annotation_confidence"] = annotation_confidences


matched = compare_texts(text_df["text"], text_df["ego_involvement_text"])

if matched:
    del text_df["ego_involvement_text"]
    
text_df.head()
# Out:
# All tweet texts match. Rows and columns are aligned!
#                                                 text  opinion_key  \
# 0  @MSNBC @MaddowBlog “Simpleton’s defense”?  You...            2
# 1  @MSNBC @MaddowBlog I feel sorry for the sucker...            1
# 2  @MSNBC @MaddowBlog Setting up a 2024 elections...            2
# 3  @MSNBC @MaddowBlog If you can't pay off studen...            1
# 4  @MSNBC @MaddowBlog The simple defense is why s...            0
#
#                       opinion_label  opinion_annotation_confidence  \
# 0  AGAINST student loan forgiveness                           0.70
# 1                   NEUTRAL support                           0.62
# 2  AGAINST student loan forgiveness                           0.43
# 3                   NEUTRAL support                           0.51
# 4     FOR student loan forgiveness                            0.88
#
#    ego_involvement_key    ego_involvement_label  \
# 0                    1       Somewhat important
# 1                    3  cannot judge importance
# 2                    2     Not important at all
# 3                    3  cannot judge importance
# 4                    1       Somewhat important
#
#    ego_involvement_annotation_confidence
# 0                                   0.95
# 1                                   0.65
# 2                                   0.81
# 3                                   0.53
# 4                                   0.69

# %% [markdown]
# ## Create a master_annotated file

# %%
master_df = pd.read_csv("../data/master.csv")

master_df.head()
# Out:
#    experiment_id experiment_group  \
# 0              1            msnbc
# 1              2            msnbc
# 2              3            msnbc
# 3              4            msnbc
# 4              5            msnbc
#
#                                                 text      tweet_id  \
# 0  @MSNBC @MaddowBlog “Simpleton’s defense”?  You...  1.596988e+18
# 1  @MSNBC @MaddowBlog I feel sorry for the sucker...  1.596993e+18
# 2  @MSNBC @MaddowBlog Setting up a 2024 elections...  1.596997e+18
# 3  @MSNBC @MaddowBlog If you can't pay off studen...  1.597006e+18
# 4  @MSNBC @MaddowBlog The simple defense is why s...  1.597023e+18
#
#    tweet_likes  retweets                tweet_created_at       user_id  \
# 0            4         0  Sun Nov 27 22:01:59 +0000 2022  1.518750e+18
# 1            0         0  Sun Nov 27 22:22:27 +0000 2022  3.202809e+09
# 2            0         0  Sun Nov 27 22:39:00 +0000 2022  1.409157e+08
# 3            2         0  Sun Nov 27 23:13:38 +0000 2022  1.933829e+09
# 4            1         0  Mon Nov 28 00:21:50 +0000 2022  1.586494e+18
#
#    in_reply_to_status_id  in_reply_to_user_id  ...  \
# 0           1.596987e+18              2836421  ...
# 1           1.596987e+18              2836421  ...
# 2           1.596987e+18              2836421  ...
# 3           1.596987e+18              2836421  ...
# 4           1.596987e+18              2836421  ...
#
#                                          description                location  \
# 0                                            No name                     NaN
# 1  People following me are president Trump suppor...      Massachusetts, USA
# 2  Hamiltonian Federalist: i.e., The United State...          Washington, DC
# 3  Rule of law makes civilized life possible. Equ...  where ever there's oil
# 4  Gay Libertarian, married, gun owner, dog daddy...                My house
#
#   followers_count      screen_name  statuses_count favourites_count  verified  \
# 0               8       BigTex1022            2333             1941     False
# 1             874  michael_favreau           30060            16373     False
# 2             375       AlxHamiltn           33016             1061     False
# 3             537      Oil_vampire           60763            19861     False
# 4               5      32926Uhtred            1102              320     False
#
#    user_id_char text_length text_word_count
# 0  1.518750e+18         183              30
# 1  3.202809e+09         114              20
# 2  1.409157e+08         148              20
# 3  1.933829e+09         226              46
# 4  1.586494e+18         159              27
#
# [5 rows x 28 columns]

# %% [markdown]
# **Remove text column from text_df and merge with master_df**

# %%
if "text" in text_df.columns: 
    del text_df["text"]
    
master_annotated_df = master_df.join(text_df)

# %% [markdown]
# ### Write merged dataframes
# Create a new `master_annotated.csv` file for review.

# %%
master_annotated_df
# Out:
#      experiment_id experiment_group  \
# 0                1            msnbc
# 1                2            msnbc
# 2                3            msnbc
# 3                4            msnbc
# 4                5            msnbc
# ..             ...              ...
# 463            464          foxnews
# 464            465          foxnews
# 465            466          usedgov
# 466            467          foxnews
# 467            468          foxnews
#
#                                                   text      tweet_id  \
# 0    @MSNBC @MaddowBlog “Simpleton’s defense”?  You...  1.596988e+18
# 1    @MSNBC @MaddowBlog I feel sorry for the sucker...  1.596993e+18
# 2    @MSNBC @MaddowBlog Setting up a 2024 elections...  1.596997e+18
# 3    @MSNBC @MaddowBlog If you can't pay off studen...  1.597006e+18
# 4    @MSNBC @MaddowBlog The simple defense is why s...  1.597023e+18
# ..                                                 ...           ...
# 463  @FoxNews I don't need any bias media to tell m...  1.599859e+18
# 464  @FoxNews He still trying to get college studen...  1.599863e+18
# 465  @usedgov why are my student loans not transfer...  1.599892e+18
# 466  @FoxNews Just another way of screwing the taxp...  1.599894e+18
# 467  @FoxNews The Democrats don’t seem to be trying...  1.599904e+18
#
#      tweet_likes  retweets                tweet_created_at       user_id  \
# 0              4         0  Sun Nov 27 22:01:59 +0000 2022  1.518750e+18
# 1              0         0  Sun Nov 27 22:22:27 +0000 2022  3.202809e+09
# 2              0         0  Sun Nov 27 22:39:00 +0000 2022  1.409157e+08
# 3              2         0  Sun Nov 27 23:13:38 +0000 2022  1.933829e+09
# 4              1         0  Mon Nov 28 00:21:50 +0000 2022  1.586494e+18
# ..           ...       ...                             ...           ...
# 463            0         0  Mon Dec 05 20:09:32 +0000 2022  1.585731e+18
# 464            4         0  Mon Dec 05 20:26:48 +0000 2022  1.581359e+18
# 465            0         0  Mon Dec 05 22:24:29 +0000 2022  7.925171e+17
# 466            0         0  Mon Dec 05 22:32:26 +0000 2022  1.518825e+18
# 467            0         0  Mon Dec 05 23:09:08 +0000 2022  1.586128e+18
#
#      in_reply_to_status_id  in_reply_to_user_id  ... verified  user_id_char  \
# 0             1.596987e+18              2836421  ...    False  1.518750e+18
# 1             1.596987e+18              2836421  ...    False  3.202809e+09
# 2             1.596987e+18              2836421  ...    False  1.409157e+08
# 3             1.596987e+18              2836421  ...    False  1.933829e+09
# 4             1.596987e+18              2836421  ...    False  1.586494e+18
# ..                     ...                  ...  ...      ...           ...
# 463           1.599767e+18              1367531  ...    False  1.585731e+18
# 464           1.599844e+18              1367531  ...    False  1.581359e+18
# 465                    NaN             20437286  ...    False  7.925171e+17
# 466           1.599351e+18              1367531  ...    False  1.518825e+18
# 467           1.599901e+18              1367531  ...    False  1.586128e+18
#
#     text_length text_word_count  opinion_key  \
# 0           183              30            2
# 1           114              20            1
# 2           148              20            2
# 3           226              46            1
# 4           159              27            0
# ..          ...             ...          ...
# 463         263              49            2
# 464         136              23            0
# 465         181              33            0
# 466         244              45            2
# 467         194              35            3
#
#                         opinion_label  opinion_annotation_confidence  \
# 0    AGAINST student loan forgiveness                           0.70
# 1                     NEUTRAL support                           0.62
# 2    AGAINST student loan forgiveness                           0.43
# 3                     NEUTRAL support                           0.51
# 4       FOR student loan forgiveness                            0.88
# ..                                ...                            ...
# 463  AGAINST student loan forgiveness                           0.94
# 464     FOR student loan forgiveness                            0.54
# 465     FOR student loan forgiveness                            0.95
# 466  AGAINST student loan forgiveness                           0.42
# 467              cannot judge support                           0.66
#
#     ego_involvement_key    ego_involvement_label  \
# 0                     1       Somewhat important
# 1                     3  cannot judge importance
# 2                     2     Not important at all
# 3                     3  cannot judge importance
# 4                     1       Somewhat important
# ..                  ...                      ...
# 463                   1       Somewhat important
# 464                   0           Very important
# 465                   1       Somewhat important
# 466                   3  cannot judge importance
# 467                   0           Very important
#
#     ego_involvement_annotation_confidence
# 0                                    0.95
# 1                                    0.65
# 2                                    0.81
# 3                                    0.53
# 4                                    0.69
# ..                                    ...
# 463                                  0.53
# 464                                  0.92
# 465                                  0.79
# 466                                  0.40
# 467                                  0.69
#
# [468 rows x 34 columns]

# %%
master_annotated_df.to_csv("../data/master_annotated.csv")
